# %% [markdown]
# # Mapping and GeoPandas
#
# By: Dr. Eric Godat

# %% [markdown]
# So far, we have explored data using tables, filtering, sorting, summary
# statistics, and plots.
#
# But many datasets also have a geographic component. Maps can reveal
# patterns that are difficult to see in a table or a scatterplot.
#
# In this notebook, we will use **GeoPandas** to:
#
# - load geographic data
# - inspect geometry columns
# - calculate areas, centroids, and distances
# - create buffers
# - test spatial relationships
# - merge geographic data with ACS data
# - map missing data
# - create choropleth maps
#
# The goal is not to become a GIS expert today. The goal is to understand
# that **location is data**.

# %% [markdown]
# # Setup

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# # 1. Reading Geographic Data

# %% [markdown]
# GeoPandas works a lot like pandas, but it adds special support for
# geographic shapes.
#
# Those shapes are stored in a special column called `geometry`.
#
# Today we will use a GeoJSON file containing Texas county boundaries.

# %%
pip install --upgrade geopandas shapely fiona
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /users/sankarana/.local/lib/python3.11/site-packages (1.1.3)
# Requirement already satisfied: shapely in /users/sankarana/.local/lib/python3.11/site-packages (2.1.2)
# Collecting fiona
#   Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
# Requirement already satisfied: numpy>=1.24 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from geopandas) (2.3.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /users/sankarana/.local/lib/python3.11/site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from geopandas) (2.3.2)
# Requirement already satisfied: pyproj>=3.5.0 in /users/sankarana/.local/lib/python3.11/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: attrs>=19.2.0 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from fiona) (25.3.0)
# Requirement already satisfied: certifi in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from fiona) (2025.8.3)
# Requirement already satisfied: click~=8.0 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from fiona) (8.2.1)
# Collecting click-plugins>=1.0 (from fiona)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting cligj>=0.5 (from fiona)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 134.5 MB/s  0:00:00
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Installing collected packages: cligj, click-plugins, fiona
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 2/3 [fiona]  WARNING: The script fio is installed in '/users/sankarana/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [fiona]
# Successfully installed click-plugins-1.1.1.2 cligj-0.7.2 fiona-1.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import shapely # map-rendering library
import numpy as np
import fiona # enging for reading more robust data files
counties = gpd.read_file("data/tx_counties.geojson", engine="fiona") # reading files using geopandas, geojson files
# json is a hierarchical file strcuture

# %% [markdown]
# If you get a If you receive a geometry-related error, update geopandas/shapely using the code below and restart the kernel.
# ```
# pip install --upgrade geopandas shapely
# ```
#
# This will upgrade the version of these packages in our environment to a newer version and resolve our error.

# %%
counties.head()
# we map polygos - n-gons, n is the number of points in the list 
# the points are describing the shape of the polygon
# geopandas take care of this for us
# for other dataframes the columns didn't matter
# but for geopandas it always expects the last column to be geometry
# Out:
#   STATE            COUNTY   FIPS STATE_FIPS  SQUARE_MIL  \
# 0    TX    Sherman County  48421         48     923.287
# 1    TX   Hansford County  48195         48     920.256
# 2    TX     Dallam County  48111         48    1505.146
# 3    TX  Ochiltree County  48357         48     917.959
# 4    TX   Lipscomb County  48295         48     932.089
#
#                                             geometry
# 0  POLYGON ((-101.62346 36.06313, -101.62346 36.0...
# 1  POLYGON ((-101.08571 36.05757, -101.08573 36.0...
# 2  POLYGON ((-103.04191 36.50043, -103.00242 36.5...
# 3  POLYGON ((-100.54614 36.49934, -100.54611 36.4...
# 4  POLYGON ((-100.00039 36.06712, -100.00039 36.0...

# %% [markdown]
# The full dataset may contain more columns than we need. Let’s look at
# just the most useful ones.

# %%
counties[["COUNTY", "FIPS", "SQUARE_MIL", "geometry"]].head()
# Out:
#              COUNTY   FIPS  SQUARE_MIL  \
# 0    Sherman County  48421     923.287
# 1   Hansford County  48195     920.256
# 2     Dallam County  48111    1505.146
# 3  Ochiltree County  48357     917.959
# 4   Lipscomb County  48295     932.089
#
#                                             geometry
# 0  POLYGON ((-101.62346 36.06313, -101.62346 36.0...
# 1  POLYGON ((-101.08571 36.05757, -101.08573 36.0...
# 2  POLYGON ((-103.04191 36.50043, -103.00242 36.5...
# 3  POLYGON ((-100.54614 36.49934, -100.54611 36.4...
# 4  POLYGON ((-100.00039 36.06712, -100.00039 36.0...

# %% [markdown]
# Each row is one county.
#
# The `geometry` column contains the county shape.

# %% [markdown]
# # 2. Our First Map
#
# GeoPandas can draw the shapes in the geometry column directly.

# %%
counties.plot(figsize=(10, 10));

# %% [markdown]
# That single line made a map.
#
# This is the basic idea of GeoPandas:
#
# > pandas dataframe + geometry column = mappable data

# %% [markdown]
# # 3. Geometry as Data
#
# The geometry column is not just for drawing maps. We can calculate
# things from it.
#
# For example, we can calculate:
#
# - area
# - boundaries
# - centroids
# - distances
# - buffers
# - intersections

# %% [markdown]
# ## Area
#
# The dataset already includes a `SQUARE_MIL` column, but GeoPandas can
# also calculate area from the geometry.

# %%
counties["geometry_area"] = counties.area
# we are not on a curved surface so that's why we get this error
# need to a mapping from euclidean to non-euclidean geometry
# different between latitude/longitude and linear distance is only noticable for longer distances - over 10 miles
# Out:
# /tmp/ipykernel_1853263/2341981245.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   counties["geometry_area"] = counties.area

# %%
counties[["COUNTY", "SQUARE_MIL", "geometry_area"]].head()
# Out:
#              COUNTY  SQUARE_MIL  geometry_area
# 0    Sherman County     923.287       0.239853
# 1   Hansford County     920.256       0.239065
# 2     Dallam County    1505.146       0.390991
# 3  Ochiltree County     917.959       0.238461
# 4   Lipscomb County     932.089       0.242137

# %% [markdown]
# Map projections affect area calculations, so `geometry_area` is not
# always in units that are easy to interpret.

# %% [markdown]
# If we need to calculate area, we first project the data into a coordinate system designed for Texas: EPSG:3083.

# %%
counties_projected = counties.to_crs("EPSG:3083")

# %%
counties_projected["area_sq_miles"] = (
    counties_projected.geometry.area / 2589988.11 #1 square mile = 2,589,988.11 square meters
)

# %%
counties_projected[["COUNTY", "SQUARE_MIL","area_sq_miles"]].sort_values(
    by="SQUARE_MIL",
    ascending=False
).head()
# Out:
#                COUNTY  SQUARE_MIL  area_sq_miles
# 181   Brewster County    6192.396    6192.420404
# 157      Pecos County    4764.812    4764.831613
# 130   Hudspeth County    4571.312    4571.265040
# 183   Presidio County    3855.419    3855.434572
# 129  Culberson County    3815.937    3815.921743

# %% [markdown]
# For today, we will use the provided `SQUARE_MIL` column when
# we want county area in square miles.

# %%
counties.sort_values(by="SQUARE_MIL", ascending=False)[["COUNTY", "SQUARE_MIL"]].head(10)
# Out:
#                COUNTY  SQUARE_MIL
# 181   Brewster County    6192.396
# 157      Pecos County    4764.812
# 130   Hudspeth County    4571.312
# 183   Presidio County    3855.419
# 129  Culberson County    3815.937
# 240       Webb County    3375.196
# 194  Val Verde County    3232.616
# 168   Crockett County    2807.477
# 133     Reeves County    2641.998
# 182    Terrell County    2357.714

# %% [markdown]
# ## Discussion
#
# Which counties are physically largest?
#
# Are those also the most populated counties?

# %% [markdown]
# # 4. Boundaries and Centroids
#
# GeoPandas can extract the boundary of each polygon.

# %%
counties_projected["boundary"] = counties_projected.boundary

# %% [markdown]
# It can also calculate the centroid, or geometric center, of each county.

# %%
counties_projected["centroid"] = counties_projected.centroid
# centroids don't really make sense for abnormal polygons like Hawaii
# can also be useful for finding distances
# average x, average y

# %%
counties_projected[["COUNTY", "boundary", "centroid"]].head()
# Out:
#              COUNTY                                           boundary  \
# 0    Sherman County  LINESTRING (1353531.629 7994292.661, 1353519.2...
# 1   Hansford County  LINESTRING (1402039.571 7993081.861, 1402035.3...
# 2     Dallam County  LINESTRING (1226914.448 8045408.138, 1230458.6...
# 3  Ochiltree County  LINESTRING (1450964.456 8041654.74, 1450961.25...
# 4   Lipscomb County  LINESTRING (1499964.75 7993659.538, 1499964.76...
#
#                           centroid
# 0  POINT (1329582.313 8018434.336)
# 1   POINT (1378081.91 8017688.094)
# 2  POINT (1265802.834 8019763.966)
# 3   POINT (1426587.75 8017316.512)
# 4  POINT (1475416.475 8016999.439)

# %% [markdown]
# Let’s plot county boundaries and county centroids together.

# %%
ax = counties_projected.plot(color="white", edgecolor="black", figsize=(10, 10))
counties_projected.set_geometry("centroid").plot(ax=ax, color="red", markersize=5);
# we are doing two graphs on top of each other
# we plotted boundaries with white fill in ax
# use ax we defined as the base and add the red dots on top of it

# %% [markdown]
# ## Discussion
#
# Is the geographic center of a county always where people live?
#
# Why might centroids be useful anyway?

# %% [markdown]
# # 5. Distance
#
# We can measure distance between geometries.
#
# Let’s pick Dallas County and calculate the distance from every county
# centroid to the Dallas County centroid.

# %%
dallas_centroid = counties_projected.loc[counties_projected["COUNTY"] == "Dallas County", "centroid"].iloc[0]
# loc slicing with conditional arguments
# iloc will select by index
# if i reorder and save something than iloc will see the first row as the first row and not the original row number

# %%
counties_projected["distance_to_dallas"] = counties_projected["centroid"].distance(dallas_centroid)

# %%
counties_projected.sort_values(by="distance_to_dallas")[["COUNTY", "distance_to_dallas"]].head(10)
# Out:
#               COUNTY  distance_to_dallas
# 78     Dallas County            0.000000
# 79   Rockwall County        37535.965373
# 98      Ellis County        46485.085166
# 77    Tarrant County        48075.028238
# 91    Kaufman County        49487.904638
# 58     Collin County        50580.720204
# 56     Denton County        58013.376444
# 97    Johnson County        69974.677295
# 57       Hunt County        75820.269961
# 111   Navarro County        84937.147348

# %% [markdown]
# The distance values depend on the coordinate system of the file, so we
# will treat them as useful for comparison rather than as precise miles.

# %%
counties_projected.plot(column="distance_to_dallas", legend=True, figsize=(10, 10));

# %% [markdown]
# ## Discussion
#
# What pattern do you expect to see before running the map?
#
# Does the map match your intuition?

# %% [markdown]
# # 6. Buffers
#
# A buffer creates an area around a geometry.
#
# You can think of this as asking:
#
# > What is within some distance of this place?

# %%
dallas_geometry = counties_projected.loc[counties_projected["COUNTY"] == "Dallas County", "geometry"].iloc[0]

# %%
dallas_buffer = dallas_geometry.buffer(100000) # EPSG:3083 uses meters, so 100 km = 100,000 meters
# you can make the buffer bigger or smaller

# %%
ax = counties_projected.plot(color="white", edgecolor="black", figsize=(10, 10))
gpd.GeoSeries([dallas_buffer], crs=counties_projected.crs).plot(ax=ax, color="orange", alpha=0.4)
gpd.GeoSeries([dallas_geometry], crs=counties_projected.crs).plot(ax=ax, color="red", alpha=0.7);

# %% [markdown]
# ## Discussion
#
# What might a buffer represent in a real project?
#
# Examples:
#
# - distance from a school
# - distance from a grocery store
# - distance from a transit stop
# - distance from a shelter
# - distance from a park

# %% [markdown]
# # 7. Spatial Relationships
#
# Spatial data lets us ask questions that ordinary tables cannot answer
# directly.
#
# For example:
#
# > Which counties touch Dallas County?

# %%
counties_projected["touches_dallas"] = counties_projected.touches(dallas_geometry)

# %%
counties_projected[counties_projected["touches_dallas"]][["COUNTY", "touches_dallas"]]
# Out:
#              COUNTY  touches_dallas
# 56    Denton County            True
# 58    Collin County            True
# 77   Tarrant County            True
# 79  Rockwall County            True
# 91   Kaufman County            True
# 98     Ellis County            True

# %%
counties_projected.plot(column="touches_dallas", categorical=True, legend=True, figsize=(10, 10));

# %% [markdown]
# We can also ask which counties intersect our Dallas buffer.

# %%
counties_projected["intersects_dallas_buffer"] = counties_projected.intersects(dallas_buffer) # includes dallas and counties that touch it

# %%
counties_projected[counties_projected["intersects_dallas_buffer"]][["COUNTY", "intersects_dallas_buffer"]].head(20)
# Out:
#              COUNTY  intersects_dallas_buffer
# 56    Denton County                      True
# 58    Collin County                      True
# 77   Tarrant County                      True
# 78    Dallas County                      True
# 79  Rockwall County                      True
# 91   Kaufman County                      True
# 97   Johnson County                      True
# 98     Ellis County                      True

# %%
counties_projected.plot(column="intersects_dallas_buffer", categorical=True, legend=True, figsize=(10, 10));

# %% [markdown]
# # 8. Merging Census Data with Geography
#
# Now we will connect this mapping work to the ACS dataset from the
# previous session.

# %%
acs = pd.read_csv("data/texas_ACS_2024_sample.csv")

# %%
acs.head()
# united states, 48th state, each county gets a number in the state
# Out:
#    Unnamed: 0         geoid                 name  Total Population  \
# 0           0  05000US48001  Anderson County, TX             58439
# 1           1  05000US48003   Andrews County, TX             18610
# 2           2  05000US48005  Angelina County, TX             87275
# 3           3  05000US48007   Aransas County, TX             24876
# 4           4  05000US48009    Archer County, TX              8867
#
#    Population 16 years and over in labor force  \
# 0                                        22510
# 1                                         8947
# 2                                        39781
# 3                                        10758
# 4                                         4263
#
#    Population 25 years and over with Bachelors Degree or higher  \
# 0                                               6511
# 1                                               1991
# 2                                              10322
# 3                                               5602
# 4                                               1608
#
#    Population 16 and over with income in the past 12 months below poverty level  \
# 0                                               5822
# 1                                               2030
# 2                                               9084
# 3                                               2755
# 4                                                626
#
#    Households with Internet Subscription  \
# 0                                  15509
# 1                                   6116
# 2                                  29340
# 3                                  11209
# 4                                   3069
#
#    Total Population in Renter Occupied Housing  \
# 0                                        13242
# 1                                         3388
# 2                                        27934
# 3                                         5005
# 4                                         1226
#
#    Median Household Income in the Past 12 Months (In 2024 Inflation-adjusted Dollars)  \
# 0                                              62068
# 1                                              72242
# 2                                              60960
# 3                                              69466
# 4                                              72159
#
#    Total Population in Owner Occupied Housing
# 0                                       34828
# 1                                       15022
# 2                                       55932
# 3                                       19600
# 4                                        7572

# %% [markdown]
# The ACS file has long column names. Let’s clean them up.

# %%
acs = acs.rename(columns={
    "name": "county",
    "Total Population": "population",
    "Population 16 years and over in labor force": "labor_force",
    "Population 25 years and over with Bachelors Degree or higher": "bachelors_degree",
    "Population 16 and over with income in the past 12 months below poverty level": "poverty_population",
    "Households with Internet Subscription": "internet_households",
    "Total Population in Renter Occupied Housing": "renters",
    "Median Household Income in the Past 12 Months (In 2024 Inflation-adjusted Dollars)": "median_income",
    "Total Population in Owner Occupied Housing": "owners"
})

# %% [markdown]
# The GeoJSON file uses a five-digit county FIPS code. The ACS file stores
# that FIPS code at the end of the `geoid` field.

# %%
acs["FIPS"] = acs["geoid"].str[-5:] # last five digits

# %% [markdown]
# Let’s create a few rates that are easier to compare across counties than
# raw totals.

# %%
acs["poverty_rate"] = acs["poverty_population"] / acs["labor_force"]
acs["bachelors_rate"] = acs["bachelors_degree"] / acs["population"]
acs["internet_rate"] = acs["internet_households"] / (acs["owners"] + acs["renters"])
acs["renter_rate"] = acs["renters"] / (acs["owners"] + acs["renters"])

# %%
acs[["county", "FIPS", "population", "median_income", "poverty_rate", "internet_rate"]].head()
# didn't change the county name like we did earlier
# this is because we now have a fips id
# Out:
#                 county   FIPS  population  median_income  poverty_rate  \
# 0  Anderson County, TX  48001       58439          62068      0.258641
# 1   Andrews County, TX  48003       18610          72242      0.226892
# 2  Angelina County, TX  48005       87275          60960      0.228350
# 3   Aransas County, TX  48007       24876          69466      0.256088
# 4    Archer County, TX  48009        8867          72159      0.146845
#
#    internet_rate
# 0       0.322634
# 1       0.332211
# 2       0.349844
# 3       0.455558
# 4       0.348829

# %% [markdown]
# Now we can merge the ACS data onto the county shapes.

# %%
mapped = counties_projected.merge(acs, on="FIPS", how="left")

# %%
mapped.head()
# Out:
#   STATE            COUNTY   FIPS STATE_FIPS  SQUARE_MIL  \
# 0    TX    Sherman County  48421         48     923.287
# 1    TX   Hansford County  48195         48     920.256
# 2    TX     Dallam County  48111         48    1505.146
# 3    TX  Ochiltree County  48357         48     917.959
# 4    TX   Lipscomb County  48295         48     932.089
#
#                                             geometry  geometry_area  \
# 0  POLYGON ((1353531.629 7994292.661, 1353519.237...       0.239853
# 1  POLYGON ((1402039.571 7993081.861, 1402035.361...       0.239065
# 2  POLYGON ((1226914.448 8045408.138, 1230458.63 ...       0.390991
# 3  POLYGON ((1450964.456 8041654.74, 1450961.256 ...       0.238461
# 4  POLYGON ((1499964.75 7993659.538, 1499964.761 ...       0.242137
#
#    area_sq_miles                                           boundary  \
# 0     923.288817  LINESTRING (1353531.629 7994292.661, 1353519.2...
# 1     920.257859  LINESTRING (1402039.571 7993081.861, 1402035.3...
# 2    1505.139988  LINESTRING (1226914.448 8045408.138, 1230458.6...
# 3     917.955570  LINESTRING (1450964.456 8041654.74, 1450961.25...
# 4     932.089331  LINESTRING (1499964.75 7993659.538, 1499964.76...
#
#                           centroid  ...  bachelors_degree  poverty_population  \
# 0  POINT (1329582.313 8018434.336)  ...               463                 162
# 1   POINT (1378081.91 8017688.094)  ...              1142                 363
# 2  POINT (1265802.834 8019763.966)  ...               511                 496
# 3   POINT (1426587.75 8017316.512)  ...              1229                 820
# 4  POINT (1475416.475 8016999.439)  ...               401                 222
#
#    internet_households  renters median_income owners  poverty_rate  \
# 0                  814      534         61250   1725      0.135906
# 1                 1673      914         69441   4134      0.138921
# 2                 2185     2377         71500   4886      0.133549
# 3                 3294     2287         70183   7427      0.166701
# 4                  892      463         72560   2403      0.178027
#
#    bachelors_rate  internet_rate  renter_rate
# 0        0.201743       0.360336     0.236388
# 1        0.223090       0.331418     0.181062
# 2        0.070019       0.300840     0.327275
# 3        0.125588       0.339098     0.235433
# 4        0.137423       0.311235     0.161549
#
# [5 rows x 28 columns]

# %% [markdown]
# Check whether the merge worked.

# %%
mapped[["COUNTY", "county", "population", "median_income"]].head()
# Out:
#              COUNTY                county  population  median_income
# 0    Sherman County    Sherman County, TX        2295          61250
# 1   Hansford County   Hansford County, TX        5119          69441
# 2     Dallam County     Dallam County, TX        7298          71500
# 3  Ochiltree County  Ochiltree County, TX        9786          70183
# 4   Lipscomb County   Lipscomb County, TX        2918          72560

# %% [markdown]
# # 9. Choropleth Maps
#
# A choropleth map colors areas based on a data value.
#
# Let’s map median household income.

# %%
mapped.plot(
    column="median_income",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
);

# see here for more info on colors
# https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %% [markdown]
# This map is more informative if we remove the axes.

# %%
ax = mapped.plot(
    column="median_income",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2,
)
ax.set_axis_off();

# %% [markdown]
# ## You Try
#
# Map `poverty_rate` instead of `median_income`.

# %%
# Your code here
ax = mapped.plot(
    column="poverty_rate",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
ax.set_axis_off();
# semi-colon at the end of the line supresses output, gets rid of python about saying it's stored in memory or something

# %% [markdown]
# # 10. Totals vs Rates
#
# Raw totals often mostly show where the most people live.
#
# Rates can reveal different kinds of patterns.
#
# Compare total population with internet access rate.

# %%
ax = mapped.plot(
    column="population",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
ax.set_axis_off();

# %%
ax = mapped.plot(
    column="internet_rate",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
ax.set_axis_off();

# %%
ax = mapped.plot(
    column="poverty_rate",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
ax.set_axis_off();

# %% [markdown]
# ## Discussion
#
# What does the population map show clearly?
#
# What does the internet access map show that the population map does not?

# %% [markdown]
# # 11. Classifying Values
#
# Sometimes maps are easier to read if values are grouped into categories.
#
# One common option is to use quantiles, which divide counties into groups
# with similar numbers of counties in each group.

# %%
pip install mapclassify
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mapclassify
#   Downloading mapclassify-2.10.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting networkx>=3.2 (from mapclassify)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=1.26 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from mapclassify) (2.3.2)
# Requirement already satisfied: pandas>=2.1 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from mapclassify) (2.3.2)
# Requirement already satisfied: scikit-learn>=1.4 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from mapclassify) (1.7.1)
# Requirement already satisfied: scipy>=1.12 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from mapclassify) (1.16.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from pandas>=2.1->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: six>=1.5 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.1->mapclassify) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from scikit-learn>=1.4->mapclassify) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Downloading mapclassify-2.10.0-py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 60.5 MB/s  0:00:00
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 112.1 MB/s  0:00:00
# Installing collected packages: networkx, mapclassify
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [mapclassify]
# Successfully installed mapclassify-2.10.0 networkx-3.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
ax = mapped.plot(
    column="median_income",
    scheme="quantiles",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
ax.set_axis_off();

# %% [markdown]
# ## Discussion
#
# How does this map differ from the previous income map?
#
# Which version is easier to interpret?

# %% [markdown]
# # 12. Adding the Parks Dataset
#
# Now we will add a second dataset: Texas state parks by county.
#
# This dataset gives us a good example of a variable that is interesting,
# geographic, and not obviously connected to the ACS variables.

# %%
parks = pd.read_csv("data/texas_state_parks_by_county.csv")

# %% [markdown]
# If your file has a slightly different name, update the path above.

# %%
parks.head()
# Out:
#           geoid county_name  state_park_count
# 0  05000US48007     Aransas                 1
# 1  05000US48015      Austin                 1
# 2  05000US48019     Bandera                 3
# 3  05000US48021     Bastrop                 2
# 4  05000US48029       Bexar                 1

# %% [markdown]
# Clean the parks data so the FIPS code matches our other datasets.

# %%
parks["FIPS"] = parks["geoid"].str[-5:]
parks = parks.rename(columns={"state_park_count": "parks"})

# %%
parks.head()
# Out:
#           geoid county_name  parks   FIPS
# 0  05000US48007     Aransas      1  48007
# 1  05000US48015      Austin      1  48015
# 2  05000US48019     Bandera      3  48019
# 3  05000US48021     Bastrop      2  48021
# 4  05000US48029       Bexar      1  48029

# %% [markdown]
# Merge parks onto our mapped data.

# %%
mapped = mapped.merge(parks[["FIPS", "parks"]], on="FIPS", how="left")

# %%
mapped[["COUNTY", "parks"]].head(10)
# Out:
#               COUNTY  parks
# 0     Sherman County    NaN
# 1    Hansford County    NaN
# 2      Dallam County    NaN
# 3   Ochiltree County    NaN
# 4    Lipscomb County    NaN
# 5     Roberts County    NaN
# 6    Hemphill County    NaN
# 7  Hutchinson County    NaN
# 8     Hartley County    NaN
# 9       Moore County    NaN

# %% [markdown]
# Some counties do not have state parks in this dataset.
#
# That gives us a chance to talk about missing data.

# %%
mapped["parks"].isna().sum()
# Out:
# np.int64(167)

# %% [markdown]
# # 13. Mapping Missing Data
#
# GeoPandas ignores missing values by default.

# %%
ax = mapped.plot(
    column="parks",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
ax.set_axis_off();

# %% [markdown]
# We can make the missing data visible using `missing_kwds`.

# %%
ax = mapped.plot(
    column="parks",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2,
    # tell it how to color the missing values
    missing_kwds={
        "color": "lightgrey",
        "edgecolor": "red",
        "hatch": "///",
        "label": "No state park listed"
    }
)
ax.set_axis_off();

# %% [markdown]
# Missing data is not always a problem to hide. Sometimes it is part of
# the story.

# %% [markdown]
# # 14. Filling Missing Values
#
# In this case, a missing value probably means the county has zero state
# parks in the parks dataset.
#
# Let’s create a filled version.

# %%
mapped["parks_filled"] = mapped["parks"].fillna(0)

# %%
ax = mapped.plot(
    column="parks_filled",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
ax.set_axis_off();

# %% [markdown]
# ## Discussion
#
# Is it reasonable to replace missing park values with zero?
#
# When would filling missing values be dangerous?

# %% [markdown]
# # 15. Comparing Maps
#
# Now we can compare the parks map to ACS variables.
#
# For example:
#
# - Are parks concentrated in high-income counties?
# - Are parks concentrated in rural counties?
# - Are parks related to population?
# - Are parks just showing geography and land availability?

# %%
mapped.plot.scatter(x="parks_filled", y="median_income");

# %%
mapped.plot.scatter(x="parks_filled", y="population");

# %%
mapped.plot.scatter(x="parks_filled", y="poverty_rate");

# %% [markdown]
# ## Discussion
#
# Do these relationships look strong, weak, or messy?
#
# What might explain the pattern?
#
# What might be misleading?

# %% [markdown]
# # 16. Layering Maps
#
# We can layer different geometries on the same map.
#
# For example, we can map county income and overlay county centroids.

# %%
ax = mapped.plot(
    column="median_income",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
mapped.set_geometry("centroid").plot(ax=ax, color="black", markersize=3)
ax.set_axis_off();

# %% [markdown]
# This is a simple example, but layering is a very important idea in
# spatial analysis.

# %% [markdown]
# # 17. Pulling it all together: Parks Within 100 km of a County
#
# Now let's tie several spatial ideas together.
#
# Suppose we want to ask:
#
# > How many state parks could someone plausibly drive to within 100 km of a given county?
#
# This example uses:
# - projections
# - centroids
# - buffers
# - spatial relationships
# - missing data
# - counting and summarizing

# %% [markdown]
# ### Important Limitation
#
# Our parks dataset counts parks by county, but it does not include the exact latitude and longitude of each park.
#
# So this is an approximation.
#
# We will estimate nearby parks by counting parks in counties whose centroids fall within 100 km of the selected county.
#
# A better version of this analysis would use the actual point locations of each state park.

# %%
# Choose a county
selected_county = "Dallas County"
# isolate chosen county
target_county = counties_projected[
    counties_projected["COUNTY"] == selected_county
]

target_county
# Out:
#    STATE         COUNTY   FIPS STATE_FIPS  SQUARE_MIL  \
# 78    TX  Dallas County  48113         48     908.613
#
#                                              geometry  geometry_area  \
# 78  POLYGON ((1780524.652 7655910.827, 1780799.879...       0.226472
#
#     area_sq_miles                                           boundary  \
# 78     908.616411  LINESTRING (1780524.652 7655910.827, 1780799.8...
#
#                            centroid  distance_to_dallas  touches_dallas  \
# 78  POINT (1801320.064 7631735.688)                 0.0           False
#
#     intersects_dallas_buffer
# 78                      True

# %%
# Create a 100 km buffer around that county
buffer_100km = target_county.geometry.buffer(100000).iloc[0]

# %%
# Merge park counts onto our projected county data
counties_with_parks = counties_projected.merge(
    parks,
    left_on="FIPS",
    right_on="FIPS",
    how="left"
)

# %%
# Counties with no matching park record should have zero parks
counties_with_parks["parks"] = (
    counties_with_parks["parks"].fillna(0)
)

# %%
# Identify counties whose centroids fall within the 100 km buffer
counties_with_parks["within_100km"] = (
    counties_with_parks["centroid"].within(buffer_100km)
)

# %%
# Count the estimated number of nearby parks
nearby_parks = counties_with_parks[
    counties_with_parks["within_100km"]
]["parks"].sum()

print(nearby_parks)
# Out:
# 14.0

# %%
# Show the counties included in the estimate
counties_with_parks[
    counties_with_parks["within_100km"]
][["COUNTY", "parks"]].sort_values(
    by="parks",
    ascending=False
)
# Out:
#                COUNTY  parks
# 39     Grayson County    2.0
# 40       Cooke County    1.0
# 57        Hunt County    1.0
# 42      Fannin County    1.0
# 56      Denton County    1.0
# 112  Somervell County    1.0
# 115     Bosque County    1.0
# 92   Van Zandt County    1.0
# 78      Dallas County    1.0
# 76      Parker County    1.0
# 110  Henderson County    1.0
# 113       Hill County    1.0
# 97     Johnson County    1.0
# 70     Hopkins County    0.0
# 37    Montague County    0.0
# 58      Collin County    0.0
# 53       Delta County    0.0
# 55        Wise County    0.0
# 96        Hood County    0.0
# 91     Kaufman County    0.0
# 80       Rains County    0.0
# 79    Rockwall County    0.0
# 77     Tarrant County    0.0
# 98       Ellis County    0.0
# 111    Navarro County    0.0
# 128  Freestone County    0.0

# %%
# Plot the result
ax = counties_projected.plot(
    color="white",
    edgecolor="lightgray",
    figsize=(10, 10)
)

# Highlight the selected county
target_county.plot(
    ax=ax,
    color="orange",
    edgecolor="black"
)

# Draw the 100 km buffer
gpd.GeoSeries([buffer_100km], crs=counties_projected.crs).plot(
    ax=ax,
    color="none",
    edgecolor="red",
    linewidth=2
)

# Highlight counties whose centroids are within the buffer
counties_with_parks[counties_with_parks["within_100km"]].plot(
    ax=ax,
    color="lightblue",
    edgecolor="black",
    alpha=0.5
)

# Plot county centroids, scaled by park count
counties_with_parks.set_geometry("centroid").plot(
    ax=ax,
    markersize=counties_with_parks["parks"] * 10,
    color="green",
    alpha=0.7
)

ax.set_title(
    f"Estimated state parks within 100 km of {selected_county} County: {nearby_parks}"
)

ax.set_axis_off()

# %% [markdown]
# ### Discussion
#
# What assumptions did we make?
#
# - We used county centroids instead of exact park locations.
# - We counted all parks in a county if that county's centroid was within the buffer.
# - We used a straight-line distance, not actual driving distance.
# - We did not consider roads, traffic, park size, or park quality.
#
# This is still useful because it shows how spatial analysis can help us build an approximate answer when perfect data is not available.
#
# What if state parks exist in multiple counties?

# %% [markdown]
# # 18. Mini-Challenge
#
# Create one map that surprises you.
#
# Choose one variable from the dataset and make a map.
#
# Possible variables:
#
# - `population`
# - `median_income`
# - `poverty_rate`
# - `bachelors_rate`
# - `internet_rate`
# - `renter_rate`
# - `parks_filled`
# - `SQUARE_MIL`
# - `distance_to_dallas`
#
# Your map should include:
#
# 1.  a variable
# 2.  a legend
# 3.  no axes
# 4.  a short interpretation

# %%
# Your map here
ax = mapped.plot(
    column="bachelors_rate",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)
ax.set_title(
    f"Rate of Bachelors Degress in Texas Counties"
)
ax.set_axis_off();

# %% [markdown]
# What pattern do you see?
#
# Why might this pattern exist?
#
# What might be misleading about this map?

# %% [markdown]
# # AI Assistant Checkpoint
#
# Try asking an AI assistant one of the following:
#
# - Explain what a geometry column is in GeoPandas.
# - Explain the difference between a choropleth map and a scatterplot.
# - Why can raw totals be misleading on maps?
# - What does it mean for two polygons to touch or intersect?
# - Help me improve this GeoPandas map without changing the data.
#
# AI tools are most useful when you ask them to explain, debug, or
# critique your work.

# %% [markdown]
# # Wrap-Up
#
# Today we learned that spatial data is more than just a picture.
#
# We used GeoPandas to:
#
# - load county boundaries
# - map geometries
# - calculate areas, centroids, distances, and buffers
# - test spatial relationships
# - merge ACS data with county shapes
# - map missing values
# - compare geographic patterns
#
# The most important idea is:
#
# > Geography changes how we interpret data.
